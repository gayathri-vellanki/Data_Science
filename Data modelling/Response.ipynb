# %%
import pandas as pd
df=pd.read_csv("superstore_data.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(len(df))
df.shape
# Out:
# 2240
# (2240, 22)

# %%
df.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    7/3/2013       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0   3/12/2012       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    1/9/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
df.isnull()
# Out:
#          Id  Year_Birth  Education  Marital_Status  Income  Kidhome  Teenhome  \
# 0     False       False      False           False   False    False     False
# 1     False       False      False           False   False    False     False
# 2     False       False      False           False   False    False     False
# 3     False       False      False           False   False    False     False
# 4     False       False      False           False   False    False     False
# ...     ...         ...        ...             ...     ...      ...       ...
# 2235  False       False      False           False   False    False     False
# 2236  False       False      False           False   False    False     False
# 2237  False       False      False           False   False    False     False
# 2238  False       False      False           False   False    False     False
# 2239  False       False      False           False   False    False     False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# ...

# %%
df["Response"].value_counts()
# Out:
# Response
# 0    1906
# 1     334
# Name: count, dtype: int64

# %%
df.drop(['Complain'],axis=1,inplace=True)

# %%
PositiveResponse = df[df["Response"] ==1]
print(PositiveResponse)
# Out:
#         Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0     1826        1970  Graduation       Divorced  84835.0        0         0
# 1        1        1961  Graduation         Single  57091.0        0         0
# 4     5371        1989  Graduation         Single  21474.0        1         0
# 5     7348        1958         PhD         Single  71691.0        0         0
# 6     4073        1954    2n Cycle        Married  63564.0        0         0
# ...    ...         ...         ...            ...      ...      ...       ...
# 2195  5153        1967         PhD        Married  77766.0        0         1
# 2196  4127        1967         PhD        Married  77766.0        0         1
# 2212  3979        1983         PhD       Divorced  90687.0        0         0
# 2216  7230        1960         PhD       Divorced  50611.0        0         1
# 2239  4070        1969         PhD        Married  94871.0        0         2
#
# ...

# %%
print(df.groupby("Response", sort=False)['NumWebPurchases'].sum())
print(df.groupby("Response", sort=False)['NumStorePurchases'].sum())
print(df.groupby("Response", sort=False)['NumCatalogPurchases'].sum())
print(df.groupby("Response", sort=False)['NumWebPurchases'].sum())
print(df.groupby("Response", sort=False)['NumDealsPurchases'].sum())
print(df.groupby("Response", sort=False)['MntGoldProds'].sum())
print(df.groupby("Response", sort=False)['MntWines'].sum())
print(df.groupby("Response", sort=False)['MntMeatProducts'].sum())
print(df.groupby("Response", sort=False)['MntFishProducts'].sum())
# Out:
# Response
# 1    1694
# 0    7456
# Name: NumWebPurchases, dtype: int64
# Response
# 1     2036
# 0    10934
# Name: NumStorePurchases, dtype: int64
# Response
# 1    1404
# 0    4559
# Name: NumCatalogPurchases, dtype: int64
# Response
# 1    1694
# 0    7456
# Name: NumWebPurchases, dtype: int64
# Response
# 1     780
# 0    4428
# Name: NumDealsPurchases, dtype: int64
# Response
# 1    20523
# 0    78086
# Name: MntGoldProds, dtype: int64
# Response
# 1    167903
# 0    512913
# Name: MntWines, dtype: int64
# Response
# 1     98314
# 0    275654
# Name: MntMeatProducts, dtype: int64
# Response
# 1    17385
# 0    66672
# Name: MntFishProducts, dtype: int64

# %%
df.drop(['Year_Birth'],axis=1,inplace=True)

# %%
df.drop(['Education'],axis=1,inplace=True)

# %%
df.drop(['Marital_Status'],axis=1,inplace=True)

# %%
df.drop(['Income'],axis=1,inplace=True)

# %%
df.drop(['Dt_Customer'],axis=1,inplace=True)

# %%
df.corr()
# Out:
#                            Id   Kidhome  Teenhome   Recency  MntWines  \
# Id                   1.000000  0.002406 -0.002580 -0.046524 -0.022878
# Kidhome              0.002406  1.000000 -0.036133  0.008827 -0.496297
# Teenhome            -0.002580 -0.036133  1.000000  0.016198  0.004846
# Recency             -0.046524  0.008827  0.016198  1.000000  0.016064
# MntWines            -0.022878 -0.496297  0.004846  0.016064  1.000000
# MntFruits            0.004600 -0.372581 -0.176764 -0.004306  0.389637
# MntMeatProducts     -0.004437 -0.437129 -0.261160  0.023056  0.562667
# MntFishProducts     -0.024475 -0.387644 -0.204187  0.001079  0.399753
# MntSweetProducts    -0.007642 -0.370673 -0.162475  0.022670  0.386581
# MntGoldProds        -0.013438 -0.349595 -0.021725  0.016693  0.387516
# NumDealsPurchases   -0.037166  0.221798  0.387741 -0.001098  0.010940
# NumWebPurchases     -0.018924 -0.361647  0.155500 -0.010726  0.542265
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as ses

# %%
df["Response"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Response'>

# %%
plt.figure(figsize=(20,10))
ses.heatmap(df.corr())
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
df[df['Response']==1]=plt.hist(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df[df['Response']==1]=hist(df)
#       2 plt.show()
#
# NameError: name 'hist' is not defined

# %%
x=df['Response']
plt.plot(x,linestyle='dotted')
plt.show()

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(df['Response'],df["NumStorePurchases"], color ='blue', 
        width = 0.4)
 
plt.xlabel("Response")
plt.ylabel("NumStorePurchases")
plt.title("Response Analysis")
plt.show()

# %%
a=[df['MntWines'],df['MntFruits'],df['MntMeatProducts'],df['MntFishProducts'],df['MntSweetProducts'],
   df['MntSweetProducts'],df['MntGoldProds'],df['NumDealsPurchases'],df['NumWebPurchases'],
  df['NumCatalogPurchases'],df['NumStorePurchases'],df['NumWebVisitsMonth']]

# %%
df.hist(column="Response")
# Out:
# array([[<Axes: title={'center': 'Response'}>]], dtype=object)

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
g=ses.PairGrid(df,x_vars=['MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts',
   'MntSweetProducts','MntGoldProds','NumDealsPurchases','NumWebPurchases',
  'NumCatalogPurchases','NumStorePurchases','NumWebVisitsMonth'],y_vars="Response")
g=g.map(plt.plot)

# %%
df.plot(x="Response",y=['MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts',
   'MntSweetProducts','MntGoldProds','NumDealsPurchases','NumWebPurchases',
  'NumCatalogPurchases','NumStorePurchases','NumWebVisitsMonth'],kind="bar",figsize=(20,20))
plt.show()

# %%
df.plot(x="Response",y=['MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts',
   'MntSweetProducts','MntGoldProds'],kind="line",figsize=(20,20))
plt.show()
