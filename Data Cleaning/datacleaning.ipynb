# %%
import pandas as pd
df=pd.read_csv("Road Accident Data.csv")

# %%
df
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0       200901BS70001      1/1/2021    Thursday      Give way or uncontrolled
# 1       200901BS70002      1/5/2021      Monday      Give way or uncontrolled
# 2       200901BS70003      1/4/2021      Sunday      Give way or uncontrolled
# 3       200901BS70004      1/5/2021      Monday           Auto traffic signal
# 4       200901BS70005      1/6/2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 307968  201091NM01760     2/18/2022    Thursday  Data missing or out of range
# 307969  201091NM01881     2/21/2022      Sunday  Data missing or out of range
# 307970  201091NM01935     2/23/2022     Tuesday      Give way or uncontrolled
# 307971  201091NM01964     2/23/2022     Tuesday      Give way or uncontrolled
# 307972  201091NM02142     2/28/2022      Sunday      Give way or uncontrolled
#
# ...

# %%
df.head(10)
# Out:
#      Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 195   200901BS70234     5/13/2021   Wednesday      Give way or uncontrolled
# 414   200901BS70488      9/4/2021      Friday           Auto traffic signal
# 476   200901BS70562     10/6/2021     Tuesday           Auto traffic signal
# 854   200901CP00246     9/24/2021    Thursday  Data missing or out of range
# 889   200901CP00294     10/5/2021      Monday      Give way or uncontrolled
# 925   200901CP00344    11/28/2021    Saturday  Data missing or out of range
# 1030  200901CW10145      1/7/2021   Wednesday           Auto traffic signal
# 1202  200901CW10380     2/17/2021     Tuesday      Give way or uncontrolled
# 1290  200901CW10504     3/22/2021      Sunday           Auto traffic signal
# 1293  200901CW10508     3/24/2021     Tuesday  Data missing or out of range
#
#      Accident_Severity   Latitude       Light_Conditions  \
# 195             Slight  51.495373               Daylight
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5305 entries, 195 to 307972
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Accident_Index              5305 non-null   object
#  1   Accident Date               5305 non-null   object
#  2   Day_of_Week                 5305 non-null   object
#  3   Junction_Control            5305 non-null   object
#  4   Junction_Detail             5305 non-null   object
#  5   Accident_Severity           5305 non-null   object
#  6   Latitude                    5305 non-null   float64
#  7   Light_Conditions            5305 non-null   object
#  8   Local_Authority_(District)  5305 non-null   object
#  9   Carriageway_Hazards         5305 non-null   object
#  10  Longitude                   5305 non-null   float64
#  11  Number_of_Casualties        5305 non-null   int64
#  12  Number_of_Vehicles          5305 non-null   int64
# ...

# %%
df['Accident_Index']
# Out:
# 195       200901BS70234
# 414       200901BS70488
# 476       200901BS70562
# 854       200901CP00246
# 889       200901CP00294
#               ...
# 307902    201091NK02693
# 307911    201091NK04184
# 307918    201091NK05765
# 307960    201091NM00770
# 307972    201091NM02142
# Name: Accident_Index, Length: 5305, dtype: object

# %%
df.describe()
# Out:
#           Latitude    Longitude  Number_of_Casualties  Number_of_Vehicles  \
# count  5305.000000  5305.000000           5305.000000         5305.000000
# mean     52.585688    -1.407661              1.395287            1.707446
# std       1.540364     1.520568              0.823175            0.955254
# min      50.043763    -7.516225              1.000000            1.000000
# 25%      51.444816    -2.428966              1.000000            1.000000
# 50%      52.206136    -1.360452              1.000000            1.000000
# 75%      53.468923    -0.167808              2.000000            2.000000
# max      60.077744     1.742940              9.000000           14.000000
#
#        Speed_limit
# count  5305.000000
# mean     46.580584
# std      16.293938
# min      20.000000
# 25%      30.000000
# 50%      40.000000
# 75%      60.000000
# max      70.000000

# %%
df.columns
# Out:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         Accident_Index  Accident Date  Day_of_Week  Junction_Control  \
# 195              False          False        False             False
# 414              False          False        False             False
# 476              False          False        False             False
# 854              False          False        False             False
# 889              False          False        False             False
# ...                ...            ...          ...               ...
# 307902           False          False        False             False
# 307911           False          False        False             False
# 307918           False          False        False             False
# 307960           False          False        False             False
# 307972           False          False        False             False
#
#         Junction_Detail  Accident_Severity  Latitude  Light_Conditions  \
# ...

# %%
df.drop(['Accident_Index'],axis=1,inplace=True)

# %%
df.drop(['Accident Date'],axis=1,inplace=True)

# %%
df
# Out:
#        Day_of_Week              Junction_Control Accident_Severity   Latitude  \
# 195      Wednesday      Give way or uncontrolled            Slight  51.495373
# 414         Friday           Auto traffic signal            Slight  51.497136
# 476        Tuesday           Auto traffic signal            Slight  51.495660
# 854       Thursday  Data missing or out of range           Serious  51.511819
# 889         Monday      Give way or uncontrolled            Slight  51.513312
# ...            ...                           ...               ...        ...
# 307902   Wednesday  Data missing or out of range            Slight  58.901246
# 307911      Monday  Data missing or out of range            Slight  58.864247
# 307918      Sunday  Data missing or out of range            Slight  59.249732
# 307960    Thursday  Data missing or out of range            Slight  56.879446
# 307972      Sunday      Give way or uncontrolled           Serious  57.575210
#
# ...

# %%
import numpy as np
import seaborn as ses
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(df['Accident_Severity'],df['Number_of_Vehicles'], color ='maroon', 
        width = 0.4)
 
plt.xlabel("Accident_Severity")
plt.ylabel("Number_of_Vehicles")
plt.title("Accident Rate")
plt.show()

# %%
x=df['Number_of_Vehicles']
plt.pie(x)
plt.title('Pie chart',fontsize=30,color='green')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['Accident_Severity'],df['Number_of_Vehicles'],c='red')
plt.show()

# %%
x=df['Number_of_Vehicles']
plt.hist(x)
plt.show()

# %%
x=df['Number_of_Vehicles']
plt.plot(x,linestyle='dotted')
plt.show()

# %%
a=[df['Latitude'],df['Longitude'],df['Number_of_Casualties'],df['Number_of_Vehicles'],df['Speed_limit']]
h=pd.DataFrame(a)
print(h)
# Out:
#                          195        414        476        854        889     \
# Latitude              51.495373  51.497136  51.495660  51.511819  51.513312
# Longitude             -0.172625  -0.158868  -0.173766  -0.098466  -0.079668
# Number_of_Casualties   2.000000   1.000000   1.000000   1.000000   1.000000
# Number_of_Vehicles     1.000000   1.000000   2.000000   1.000000   1.000000
# Speed_limit           30.000000  30.000000  30.000000  30.000000  30.000000
#
#                          925        1030       1202       1290       1293    \
# Latitude              51.512962  51.518841  51.512778  51.523720  51.511520
# Longitude             -0.096833  -0.121236  -0.193258  -0.145254  -0.130185
# Number_of_Casualties   2.000000   1.000000   1.000000   1.000000   1.000000
# Number_of_Vehicles     1.000000   3.000000   2.000000   1.000000   1.000000
# Speed_limit           30.000000  30.000000  30.000000  30.000000  30.000000
#
# ...

# %%
h.corr()
# Out:
#           195       414       476       854       889       925       1030    \
# 195     1.000000  0.999837  0.999532  0.999828  0.999824  0.999999  0.998898
# 414     0.999837  1.000000  0.999837  0.999999  0.999999  0.999847  0.999358
# 476     0.999532  0.999837  1.000000  0.999827  0.999824  0.999530  0.999842
# 854     0.999828  0.999999  0.999827  1.000000  1.000000  0.999839  0.999340
# 889     0.999824  0.999999  0.999824  1.000000  1.000000  0.999837  0.999335
# ...          ...       ...       ...       ...       ...       ...       ...
# 307902  0.940105  0.940837  0.940105  0.940701  0.940669  0.939946  0.938884
# 307911  0.939970  0.940704  0.939970  0.940568  0.940536  0.939811  0.938747
# 307918  0.941437  0.942197  0.941437  0.942066  0.942036  0.941284  0.940194
# 307960  0.929877  0.930590  0.930558  0.930400  0.930353  0.929651  0.929988
# 307972  0.934818  0.935468  0.934819  0.935314  0.935277  0.934637  0.933663
#
# ...

# %%
plt.figure(figsize=(20,10))
ses.heatmap(h.corr())
plt.show()
